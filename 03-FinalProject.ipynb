# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report section Title & Abstract trhough Data Wrangling:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#
# For the report section Data Visualizations through Documentation and Written Communication:
# - Each Developing  => -1 pts
# - Each Unsatisfactory/Missing => -2 pts
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# Until the score is 0
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Ethics                                                                             | No effort or just says we have no ethical concerns                                                                                                                                                                                                                                                  | Minimal ethical section; probably just talks about data privacy and no unintended consequences discussion. Ethical concerns raised seem irrelevant.                                                                                                                                                 | The ethical concerns described are appropriate and sufficiently                                                                                                                                                                                                                                                                     | Ethical concerns are described clearly and succinctly. This was clearly a thorough and nuanced approach to the issues                                                                                                                                                                                                          |
# | Data visualizations                                                                | No plots. Or most plots don't capture useful information, or their display of information is difficult to understand. Legends, labels, axes, titles, captions, etc of most plots may be poor or missing. Most figures are not referenced in the main text.                                          | Fewer than 3 relevant plots (irrelevant to the question plots do not count).  Or a few of the plots don't make sense or capture useful information. Legends, labels, axes, titles, captions, etc are illegible or inadequately describe the content in a few figures. Or a few figures are not referenced or explained inside the main text. | Plots almost all make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | No analyses beyond EDA style explorations of the dataset. Or analyses presented do not help address the question/hypothesis. Or most of the analyses presented are not technically approriate (eg. using parametric methods for non-parametric data).                                              | Only one analysis beyond EDA. Or a few analyses presented do not address the question/hypothesis. Or a few of the analyses presented are not technically approriate                                                                                                                                                                  |  At least two analyses beyond EDA. That is, the project uses two different techniques (e.g., inference vs machine learning; or t-test vs regression; or entire dataset vs stratified) or two different proxies for the same concept are investigated.  Each analysis addressed the question/hypothesis and is technically approriate. | Many different analyses are used. Each analysis addressed an aspect of the question/hypothesis and is technically approriate. Perhaps they use multiple datasets, or do something else to go the extra mile and address the reliability of the results                                            |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [x] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Life expectancy and health science have drastically increased and improved since the 1960s until the 2020s. However, the level of change that occurs nation to nation differ based on factors such as geography, politics, and development of that country. This project sets out to determine which factors actually impact life expenctancy the most, and if those factors have less or more extreme effects on the total results as a country is more developed. Specifically, we examine the relationships among life expectancy, GDP per capita, healthcare spending, and geographic location.
#
# To research this question, we first combined datasets containing life expectancy, healthcare spending, economic indicators, and country geographic information. We wrangled the data and deleted columns that we didn't see necessary to the overall question, and ran a quick sanity check to remove outliers that may affect our dataset. We then categorized the countries based on GDP per capita to determine if they were first, second or third world countries. We then executed exploratory data analysis to determine the long term trends of life expectancy and factors such as GDP per capita, healthcare spending and others. We also ran correlation analysis to see how these trends changed over time.
#
# Our results concluded that GDP per capita proved to be the strongest factor towards increased life expectancy, while healthcare spending proved to be another strong positive factor towards increased life expenctancy. Some of the weaker factors were geographical location. The final conclusion showed that the main driving force to increased life expenctancy was economic growth; however, since GDP per capita proved to be the strongest factor, it also shows that country development is also a key factor and the most important factor towards increasing life expectancy.

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# Example team list and credits:
# - Achintya Rai:
# - Felix Wu:
# - Josh Victoria:
# - Henry Liang:

# %% [markdown]
# ## Research Question

# %% [markdown]
# How well geographic and demographic factors predict life expectancy between first, second and third world countries across decades from 1960 to today. Do the most important factors change over time? Do some factors lose predictive weight as nations transition between economic tiers?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# **Updated**\
# Since the 1950's human life expectancy, has skyrocketed. Most people today have higher life expectancies than the richest countries in 1950 <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1). Global health inequality has also diminished significantly since the 1950s; a newborn in some countries in the 1950s could expect to live twice as much as a newborn in other countries. An interesting factor to note is that a big factor in contributing to these higher life expectancies is the higher infant mortality rates in the 1950s that skews the number a bit, however, life expectancy has still increased for all ages regardless <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2).
#
# There exists a lot of prior research on topics of what has helped increase global life expectancy. A study in the Jounrnal of Economics identifies factors that contributed to this as improved nutrition, better public health through government, urbanization, vaccination, and medical improvements. Furthermore, since WW2 (1945), poor countries have gained rapid improvements in life expectancy, with some gaining over one year per year <a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3). It's interesting to note that this may imply life expectancy correlates with diminishing returns, where a lot of gains can be made from basic quaility of life changes, however it starts plateuing at the top.
#
# A useful graph to track changes across time is called the Preston Curve. This graph plots life expectancy against GDP. Over time, this curve has been observed to have risen, which matches with what we expect given the higher life expectancy. However, it is equally important to note that while this trend holds as a large, individual countries have been observed displaying the opposite trend at times as well. <a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4). This brings up an important distinction that while income is a good predictor of health, there are still other factors at play in determining life expectancy.
#
# Furthermore, while the Preston Curve illustrates that GDP is a foundational predictor, its flattening at higher income levels suggests a transition in the underlying drivers of longevity. This project aims to move beyond aggregate economic metrics to identify which specific geographic and demographic factors (such as urbanization rates, education levels, or climate stability) gain predictive weight as nations move up the economic tier. By analyzing these shifts across decades, we seek to determine if the "formula" for increasing life expectancy has fundamentally changed, and whether certain variables that were critical in a 1960s "Third World" context have lost their predictive power in the modern era.
#
# When countries transition into a different economic tier, it can be broadly attributed to a couple of factors using a long time scale. These factors are energy use, trade, capital, labour, human capital development and foreign direct investment <a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note5).However interestingly enough in a short time frame, human capitial has a negative impact, while energy usage and foreign direct investment have a positive impact. <a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note5).
#
# And whenever countries shift economic tiers and grow towards the top of the Preston Curve, it can be seen that the factors that affected life expectancy the most stop having such a huge effect while other factors grow in importance. This can be seen with the shift in effect of certain diseases. In developing countries, infectious diseases is what affects life expectancy the most through other factors like access to clean water. But once countries develop more, they increase access to these factors that decreases risk of infectious disease so more people develop chronic illness which then affect thier life expectancy <a name="cite_ref-6"></a>[<sup>6</sup>](#cite_note6). As countries shift on the Preston Curve, different factors lose their weight on life expectancy and other factors replace them.
#
#
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Saloni Dattani, Lucas Rodés-Guirao, Hannah Ritchie, Esteban Ortiz-Ospina, and Max Roser (2023) - “Life Expectancy” Published online at OurWorldinData.org. Retrieved from: 'https://ourworldindata.org/life-expectancy' [Online Resource]
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Max Roser (2018) - “Twice as long — life expectancy around the world” Published online at OurWorldinData.org. Retrieved from: 'https://archive.ourworldindata.org/20251125-173858/life-expectancy-globally.html' [Online Resource] (archived on November 25, 2025).
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Cutler, David, Angus Deaton, and Adriana Lleras-Muney. 2006. "The Determinants of Mortality." Journal of Economic Perspectives 20 (3): 97–120.
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Preston, Samuel H. “The Changing Relation between Mortality and Level of Economic Development. 1975.” Bulletin of the World Health Organization, U.S. National Library of Medicine, 2004, pmc.ncbi.nlm.nih.gov/articles/PMC2572360/.
# 5. <a name='cit_note-5'></a> [^](#cite_ref-5) Rahman, Mohammad Mafizur, and Khosrul Alam. “Exploring the Driving Factors of Economic Growth in the World’s Largest Economies.” Heliyon, U.S. National Library of Medicine, 24 May 2021, pmc.ncbi.nlm.nih.gov/articles/PMC8180624/#:~:text=Energy%20use%2C%20trade%2C%20capital%2C,countries%20in%20the%20long%20run.
# 6. <a name='cit_note-6'></a> [^](#cite_ref-6) Omran, Abdel R. “The epidemiologic transition: a theory of the epidemiology of population change. 1971.” The Milbank quarterly vol. 83,4 (2005): 731-57. doi:10.1111/j.1468-0009.2005.00398.x

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# **Updated** \
# We predict a strong correlation between extreme climates and development of the nations and life expectancy. We noticed in our background research that countries' life expectancy has increased ever since countries got wealthier. We predict that extreme temperatures (hot above 38°C (100.4°F)  or cold under -10°C (14°F) ) and lower developed nations will cause a lower life expectancy as extreme temperatures and less developed nations have less ways and medicine to help life expectancy. We also predict that as nations get more advanced (such as moving from developed countries to emerging economies) factors such as extreme temperatures would cause less noticeable changes in life expectancy as technology would get more advanced to offset the effects of the climate. We will determin a nations development with gdp per capita ($45k+ is developed, Under 15k is developing, and between 15k and $45k as transitional)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name: Life Expectancy
#   - Link to the dataset: https://www.kaggle.com/datasets/belbino/life-expectancy-healthcare-spending-1960-present/data?select=life_expectancy.csv
#   - Number of observations: 17191
#   - Number of variables:
#   - Description of the variables most relevant to this project: The most important variable was le_total_yoy_change since it represented the total overall change from year to year. This variable is what we used to normalize our data, as well as use for our pairplot.
#   - Descriptions of any shortcomings this dataset has with repsect to the project: Some values are very far from the mean (20+ standard deviations) so we had to establish what we wanted to include, which might limit some of the third world countries.
# - Dataset #2
#   - Dataset Name: Health Spending
#   - Link to dataset: https://www.kaggle.com/datasets/belbino/life-expectancy-healthcare-spending-1960-present/data?select=health_spending.csv
#   - Number of observations: 16,000
#   - Number of variables:
#   - Description of the variables most relevant to this project: spend_per_capita_yoy_pct, spend_pct_gdp_yoy_change, and health_spend_per_capita_usd are the most important variables. We used spend_pct_gdp_yoy_change to check for outliers and was the reason we took an extra step to verify out data. Next we used spend_pct_gdp_yoy_change and health_spend_per_capita_usd to observe the 5 highest and lowest spending countries and plot and visualize.
#   - Descriptions of any shortcomings this dataset has with repsect to the project: There are also a lot of observations that are far from the mean; however, this case is different since after we plotted it and did some research, it seems like that was a result of political instability. The political instability resulted in a drastic decrease in healthcare spending. This was a concern for our dataset, but we decided it was necessary to include. Another shortcoming is the fact that the variable spend_pct_gdp_yoy_change has a null value for the first observed year. Since we don't want to get rid of the first year, we will need to work around that.
#
# Each dataset deserves either a set of bullet points as above or a few sentences if you prefer that method.
#
# If you plan to use multiple datasets, add a few sentences about how you plan to combine these datasets.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/airline-safety/airline-safety.csv', 'filename':'airline-safety.csv'},
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/bad-drivers/bad-drivers.csv', 'filename':'bad-drivers.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Overall Download Progress:  50%|█████     | 1/2 [00:00<00:00,  4.03it/s]
# Successfully downloaded: airline-safety.csv
# Overall Download Progress: 100%|██████████| 2/2 [00:00<00:00,  4.43it/s]
# Successfully downloaded: bad-drivers.csv

# %% [markdown]
# ### Dataset #1 (Life Expectancy)
#
# Life Expectancy:
# This dataset focuses on global life expectancy metrics over time, specifically tracking annual changes and gender-based disparities. It contains 17191 observations across several key variables (after dropping empty columns like region and income_group). The data is geographical, allowing for an analysis of how longevity shifts year-over-year across different countries.
#
# We had to wrangle a lot of the data and include values that were 1.5 standard deviations within the mean. Since there were certain outliers like Central African Republic were over 20+ standard deviations from the mean due to missing data, we thought that would negatively impact the data. After dropping observations that were over 1.5 standard deviations away and dropping null values, we ended with ~16000 observations.

# %%
# imports
import pandas as pd
import seaborn as sns

# %%
# Data is already tidy
life_df = pd.read_csv("./data/00-raw/life_expectancy.csv")
life_df
# Out:
#       country_code country_name  year  life_expectancy_total  \
# 0               1A   Arab World  1960              44.794056
# 1               1A   Arab World  1961              45.545371
# 2               1A   Arab World  1962              45.993769
# 3               1A   Arab World  1963              46.979338
# 4               1A   Arab World  1964              47.570034
# ...            ...          ...   ...                    ...
# 17186           ZW     Zimbabwe  2020              61.530000
# 17187           ZW     Zimbabwe  2021              60.135000
# 17188           ZW     Zimbabwe  2022              62.360000
# 17189           ZW     Zimbabwe  2023              62.775000
# 17190           ZW     Zimbabwe  2024              63.064000
#
#        life_expectancy_female  life_expectancy_male  \
# 0                   46.917488             42.850127
# 1                   47.709109             43.558405
# 2                   48.172152             44.005079
# ...

# %%
# Size of dataset
life_df.shape
# Out:
# (17191, 11)

# %%
# Region, income group and iso2_code are missing for all entries
life_df.isna().sum()
# Out:
# country_code                     65
# country_name                      0
# year                              0
# life_expectancy_total             0
# life_expectancy_female            0
# life_expectancy_male              0
# life_expectancy_gender_gap        0
# le_total_yoy_change             265
# region                        17191
# income_group                  17191
# iso2_code                     17191
# dtype: int64

# %%
life_df = life_df.drop(columns=["region", "income_group", "iso2_code", "country_code"])

# %%
# le_total_yoy_change has some very large outliers compared to the standard deviation
life_df.describe()
# Out:
#                year  life_expectancy_total  life_expectancy_female  \
# count  17191.000000           17191.000000            17191.000000
# mean    1992.037287              64.871650               67.452088
# std       18.757761              11.082195               11.569944
# min     1960.000000              10.989000               11.274000
# 25%     1976.000000              57.847500               59.985000
# 50%     1992.000000              67.253063               70.053000
# 75%     2008.000000              73.034000               76.238808
# max     2024.000000              86.497000               88.626000
#
#        life_expectancy_male  life_expectancy_gender_gap  le_total_yoy_change
# count          17191.000000                17191.000000         16926.000000
# mean              62.428309                    5.023767             0.305751
# std               10.691525                    2.188746             1.275092
# ...

# %%
# There are many entries with le_total_yoy_change over 30 std away
life_df.sort_values("le_total_yoy_change")
# Out:
#                                             country_name  year  \
# 2584                            Central African Republic  2009
# 11440                                             Rwanda  1994
# 6966                                            Cambodia  1975
# 12477                                 Somalia, Fed. Rep.  1991
# 2597                            Central African Republic  2022
# ...                                                  ...   ...
# 16866                          Latin America & Caribbean  1960
# 16931                                             Zambia  1960
# 16996  Middle East, North Africa, Afghanistan & Pakistan  1960
# 17061                                   IDA & IBRD total  1960
# 17126                                           Zimbabwe  1960
#
#        life_expectancy_total  life_expectancy_female  life_expectancy_male  \
# 2584               14.665000               20.006000             12.383000
# ...

# %%
# Removing outlier year changes (keeping within 1.5 std)
std = life_df.describe()["le_total_yoy_change"]["std"]
life_df = life_df[life_df["le_total_yoy_change"].abs() < 1.5 * std]

# %%
sns.pairplot(life_df)

# %%
life_df.isna().sum() # removing outliers in life expectancy got rid of null entries as well
# Out:
# country_name                  0
# year                          0
# life_expectancy_total         0
# life_expectancy_female        0
# life_expectancy_male          0
# life_expectancy_gender_gap    0
# le_total_yoy_change           0
# dtype: int64

# %% [markdown]
# ### Dataset #2 (Health Spending)
# Health Spending:
# Right now, we are mainly concerned with the country_name, health_spending_per_capita. The health_spending column is in thousands of dollars. The mean health_spending_per_capita is 973K and the change in spending per year is 0.55. The standard deviation is 170K and the change is 0.77.
#
# We initially thought there would be outliers, most notably +-11 percent change in some countries. However, after plotting them out, and doing research on the specific years that we found issues, we found that they weren't actually outliers, or rather data to show instability in those areas. For example, in the Democratic Congo Republic, we saw a heavy dip in 2001; however, that was due to political instability after the President was assassinated. This helps answer one of our questions of the differing relationships of first and third world countries. For cleaning data, we found that we couldn't simply drop null values since for spend_pct_gdp_yoy_change, the first recorded year wouldn't have a previous percent change which resulted in a null value, but that data is still important for our analysis, so we didn't drop any observations.

# %%
health_spending = pd.read_csv("./data/00-raw/health_spending.csv")
health_spending
# Out:
#      country_code country_name  year  health_spend_pct_gdp  \
# 0              1A   Arab World  2000              3.941685
# 1              1A   Arab World  2001              4.222019
# 2              1A   Arab World  2002              4.200567
# 3              1A   Arab World  2003              3.995481
# 4              1A   Arab World  2004              3.730702
# ...           ...          ...   ...                   ...
# 5711           ZW     Zimbabwe  2019              3.232682
# 5712           ZW     Zimbabwe  2020              2.954401
# 5713           ZW     Zimbabwe  2021              2.671119
# 5714           ZW     Zimbabwe  2022              3.395195
# 5715           ZW     Zimbabwe  2023              2.926016
#
#       health_spend_per_capita_usd  spend_pct_gdp_yoy_change  \
# 0                      111.859375                       NaN
# 1                      114.541456                     0.280
# 2                      113.335666                    -0.021
# ...

# %%
# Dataset size
health_spending.shape
# Out:
# (5716, 11)

# %%
# Missing data
health_spending.isna().sum()
# Out:
# country_code                     24
# country_name                      0
# year                              0
# health_spend_pct_gdp              0
# health_spend_per_capita_usd       3
# spend_pct_gdp_yoy_change        241
# spend_per_capita_yoy_pct        241
# spend_tier                        0
# region                         5716
# income_group                   5716
# iso2_code                      5716
# dtype: int64

# %%
health_spending = health_spending.drop(columns=["region", "income_group", "iso2_code"])

# %%
# Some years seem to have extreme change in funding
health_spending.describe()
# Out:
#               year  health_spend_pct_gdp  health_spend_per_capita_usd  \
# count  5716.000000           5716.000000                  5713.000000
# mean   2011.633135              6.200607                   973.114634
# std       6.950490              2.816016                  1758.592218
# min    2000.000000              1.222602                     4.175786
# 25%    2006.000000              4.203753                    64.677567
# 50%    2012.000000              5.463015                   253.982468
# 75%    2018.000000              7.827612                   841.248840
# max    2024.000000             27.089685                 13473.193359
#
#        spend_pct_gdp_yoy_change  spend_per_capita_yoy_pct
# count               5475.000000               5475.000000
# mean                   0.055409                  7.049622
# std                    0.767773                 14.091045
# min                  -11.515000                -68.980000
# ...

# %%
low_spending_names = health_spending.sort_values("spend_per_capita_yoy_pct")["country_name"][:5].unique()
high_spending_names = health_spending.sort_values("spend_per_capita_yoy_pct", ascending=False)["country_name"][:5].unique()

# %%
# Outliers seem to be fine, and not due to missing/wrong data
low_spending = health_spending[health_spending["country_name"].isin(low_spending_names)]
sns.lineplot(low_spending, y="health_spend_per_capita_usd", x="year", hue="country_name")
# Out:
# <Axes: xlabel='year', ylabel='health_spend_per_capita_usd'>

# %%
high_spending = health_spending[health_spending["country_name"].isin(high_spending_names)]
sns.lineplot(high_spending, y="health_spend_per_capita_usd", x="year", hue="country_name")
# Out:
# <Axes: xlabel='year', ylabel='health_spend_per_capita_usd'>

# %%
health_spending_null = health_spending[health_spending.isna().any(axis=1)]
health_spending_null
# Out:
#      country_code                                       country_name  year  \
# 0              1A                                         Arab World  2000
# 24             1W                                              World  2000
# 48             4E        East Asia & Pacific (excluding high income)  2000
# 72             7E      Europe & Central Asia (excluding high income)  2000
# 96             8S                                         South Asia  2000
# ...           ...                                                ...   ...
# 5606           ZJ                          Latin America & Caribbean  2000
# 5630           ZM                                             Zambia  2000
# 5654           ZQ  Middle East, North Africa, Afghanistan & Pakistan  2000
# 5678           ZT                                   IDA & IBRD total  2000
# 5702           ZW                                           Zimbabwe  2010
#
#       health_spend_pct_gdp  health_spend_per_capita_usd  \
# ...

# %%
health_spending_null[health_spending_null["year"] != 2000]
# Out:
#      country_code        country_name  year  health_spend_pct_gdp  \
# 168            AF         Afghanistan  2002              9.443391
# 1103           CU                Cuba  2021             13.787466
# 1104           CU                Cuba  2022             11.787735
# 1105           CU                Cuba  2023              9.383831
# 2098           IQ                Iraq  2003              2.996936
# 2554           LI       Liechtenstein  2013              5.749430
# 2807           ME          Montenegro  2011              7.966922
# 3157          NaN             Namibia  2001             10.465676
# 3158          NaN             Namibia  2002             10.478712
# 3159          NaN             Namibia  2003             10.744746
# 3160          NaN             Namibia  2004             10.885438
# 3161          NaN             Namibia  2005             10.825065
# 3162          NaN             Namibia  2006             11.302900
# ...

# %%
health_spending[health_spending["country_name"] == "Zimbabwe"]
# Out:
#      country_code country_name  year  health_spend_pct_gdp  \
# 5702           ZW     Zimbabwe  2010             10.475753
# 5703           ZW     Zimbabwe  2011              8.081707
# 5704           ZW     Zimbabwe  2012              6.918387
# 5705           ZW     Zimbabwe  2013              7.110222
# 5706           ZW     Zimbabwe  2014              8.133513
# 5707           ZW     Zimbabwe  2015              7.452041
# 5708           ZW     Zimbabwe  2016              7.258456
# 5709           ZW     Zimbabwe  2017              6.174489
# 5710           ZW     Zimbabwe  2018              4.673280
# 5711           ZW     Zimbabwe  2019              3.232682
# 5712           ZW     Zimbabwe  2020              2.954401
# 5713           ZW     Zimbabwe  2021              2.671119
# 5714           ZW     Zimbabwe  2022              3.395195
# 5715           ZW     Zimbabwe  2023              2.926016
#
#       health_spend_per_capita_usd  spend_pct_gdp_yoy_change  \
# ...

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# We combine the cleaned life expectancy and health spending tables with GDP (`context.csv`) and country coordinates (`country_metadata.csv`). Outlier filtering on `le_total_yoy_change` (±1.5 SD) matches the data checkpoint. Development tiers follow our hypothesis: **developing** (&lt; $15k GDP per capita), **transitional** ($15k–$45k), **developed** (≥ $45k).
#
# Panel construction lives in `modules/eda_utils.py` (`build_analysis_panel`). Health spending is left-joined because it only exists from 2000 onward; life expectancy and GDP span 1961–2024 after filtering.
#
# The processed file below can be reloaded without re-running wrangling above.

# %% [markdown]
# #### Section 1 — Life expectancy trends by development tier (1961–2024)
#
# **What:** Median life expectancy over time, stratified by our GDP-based development tiers.
#
# **Why:** Our research question asks whether longevity gains differ across economic tiers and decades. Medians are used because life expectancy and GDP are right-skewed with occasional crisis-year drops.

# %%
import sys
sys.path.append("./modules")

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from eda_utils import build_analysis_panel, tier_order

sns.set_theme(style="whitegrid", context="notebook")

# Build once and save so this section reloads quickly
panel = build_analysis_panel()
panel.to_csv("data/02-processed/analysis_panel.csv", index=False)

panel = pd.read_csv("data/02-processed/analysis_panel.csv")
panel["dev_tier"] = pd.Categorical(panel["dev_tier"], categories=tier_order(), ordered=True)

print(f"{len(panel):,} country-years | 1961-2024")
print(panel["dev_tier"].value_counts(dropna=False))
# Out:
# 16,456 country-years | 1961-2024
# dev_tier
# developing      11639
# NaN              2440
# transitional     1766
# developed         611
# Name: count, dtype: int64

# %%
tier_ts = (
    panel.dropna(subset=["dev_tier", "life_expectancy_total"])
    .groupby(["year", "dev_tier"], observed=True)["life_expectancy_total"]
    .median()
    .reset_index()
)

fig, ax = plt.subplots(figsize=(10, 5))
sns.lineplot(
    data=tier_ts,
    x="year",
    y="life_expectancy_total",
    hue="dev_tier",
    hue_order=tier_order(),
    palette="viridis",
    linewidth=2,
    ax=ax,
)
ax.set(
    title="Median life expectancy by development tier",
    xlabel="Year",
    ylabel="Life expectancy at birth (years)",
)
ax.legend(title="Development tier")
plt.tight_layout()
plt.show()

# %%
snapshots = panel[panel["year"].isin([1970, 2000, 2024])].dropna(subset=["dev_tier", "life_expectancy_total"])

fig, ax = plt.subplots(figsize=(9, 5))
sns.boxplot(
    data=snapshots,
    x="year",
    y="life_expectancy_total",
    hue="dev_tier",
    hue_order=tier_order(),
    ax=ax,
)
ax.set(
    title="Distribution of life expectancy at three time points",
    xlabel="Year",
    ylabel="Life expectancy at birth (years)",
)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation:** All three development tiers gained years of life expectancy since the 1960s, reflecting substantial improvements in global health outcomes over time. Developing countries started at much lower life expectancy levels but experienced the largest absolute gains, while developed countries consistently maintained the highest median life expectancy throughout the period. The gap between developing and developed countries narrowed considerably through the 1990s and 2000s, consistent with the global catch-up effect described by the Preston curve literature. However, the persistent separation between the tier-specific trends suggests that economic development remains strongly associated with longevity. The fact that the lines rarely cross supports using GDP-based development tier as an important stratification variable in later correlation and regression analyses.

# %% [markdown]
# #### Section 2 — Economic and geographic predictors across tiers and decades
#
# **What:** Preston-style plots (life expectancy vs. log GDP), absolute latitude vs. life expectancy, and decade-level correlations among key variables.
#
# **Why:** We need to see whether GDP and geography relate to longevity differently by tier and whether those relationships change over time—central to our question about shifting predictive weight.

# %%
recent = panel[panel["year"] >= 2015].dropna(
    subset=["life_expectancy_total", "log_gdp_per_capita", "dev_tier"]
)

fig, ax = plt.subplots(figsize=(8, 5))
sns.scatterplot(
    data=recent,
    x="log_gdp_per_capita",
    y="life_expectancy_total",
    hue="dev_tier",
    hue_order=tier_order(),
    alpha=0.5,
    s=35,
    ax=ax,
)
ax.set(
    title="Preston curve snapshot (2015–2024)",
    xlabel="Log GDP per capita (USD)",
    ylabel="Life expectancy at birth (years)",
)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation:** Life expectancy increases with log GDP per capita but flattens at higher income levels, demonstrating the classic Preston curve relationship. The steepest gains occur among lower-income countries, where increases in GDP are associated with large improvements in longevity, while gains become smaller among wealthier countries. Developed countries cluster in the upper-right portion of the plot with consistently high life expectancy, whereas developing countries show greater vertical spread at similar GDP levels. This variation indicates that factors beyond GDP may also influence life expectancy such as healthcare systems, conflict, education, or climate may also influence life expectancy and should be considered in later regression analyses.

# %%
geo = panel.dropna(subset=["abs_latitude", "life_expectancy_total", "dev_tier"])

fig, ax = plt.subplots(figsize=(8, 5))
sns.scatterplot(
    data=geo[geo["year"] >= 2015],
    x="abs_latitude",
    y="life_expectancy_total",
    hue="dev_tier",
    hue_order=tier_order(),
    alpha=0.5,
    s=35,
    ax=ax,
)
ax.set(
    title="Geography proxy: |latitude| vs. life expectancy (2015–2024)",
    xlabel="Absolute latitude (degrees)",
    ylabel="Life expectancy at birth (years)",
)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation:** We do not yet have temperature data in the panel, so absolute latitude serves as a coarse geographic proxy for climatic differences between tropical and temperate regions. The relationship between latitude and life expectancy appears weak, with countries exhibiting substantial variation in life expectancy across nearly all latitude ranges. Countries at similar latitudes often exhibit very different life expectancy levels, with developed countries generally clustering at higher values than developing countries across much of the latitude range. This suggests that geography alone cannot explain differences in longevity and motivates adding direct climate variables in future analyses while retaining development-tier stratification in later models.

# %%
corr_vars = [
    "life_expectancy_total",
    "log_gdp_per_capita",
    "health_spend_pct_gdp",
    "health_spend_per_capita_usd",
    "abs_latitude",
]
decades = [1960, 1980, 2000, 2020]

fig, axes = plt.subplots(2, 2, figsize=(11, 9))
for ax, decade in zip(axes.flat, decades):
    subset = panel[panel["decade"] == decade][corr_vars].dropna(how="all")
    c = subset.corr(numeric_only=True)
    sns.heatmap(
        c,
        annot=True,
        fmt=".2f",
        cmap="coolwarm",
        vmin=-1,
        vmax=1,
        ax=ax,
        cbar_kws={"shrink": 0.8},
    )
    ax.set_title(f"{decade}s")
plt.suptitle("Correlations by decade", y=1.02)
plt.tight_layout()
plt.show()

# %%
health_era = panel.dropna(
    subset=["life_expectancy_total", "health_spend_per_capita_usd"]
)

fig, ax = plt.subplots(figsize=(8, 5))
sns.scatterplot(
    data=health_era[health_era["year"] >= 2015],
    x="health_spend_per_capita_usd",
    y="life_expectancy_total",
    hue="dev_tier",
    hue_order=tier_order(),
    alpha=0.5,
    s=35,
    ax=ax,
)
ax.set_xscale("log")
ax.set(
    title="Health spending vs. life expectancy (2015–2024)",
    xlabel="Health spend per capita (USD, log scale)",
    ylabel="Life expectancy at birth (years)",
)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation:** The correlation matrices show that the relationship between GDP per capita and life expectancy remains consistently strong across all decades, supporting the idea that economic development is a major predictor of longevity. Absolute latitude exhibits a weaker but generally positive correlation with both GDP and life expectancy, suggesting that geographic factors may influence health outcomes indirectly through development patterns. Beginning in the 2000s, health-spending variables become available and show positive correlations with life expectancy, particularly for per-capita spending. Health spending per capita is positively correlated with GDP, indicating that wealthier countries generally spend more on healthcare. These patterns suggest that GDP and healthcare investment will be important predictors in later regression models, while climate variables may help explain additional variation not captured by economic factors alone.

# %% [markdown]
# ### Analysis 1 — OLS regression by development tier (2000–2024)
#
# We use `statsmodels.formula.api.ols` (`smf.ols`) to predict life expectancy from log GDP, absolute latitude, and health spending per capita. We fit one model per development tier so we can compare coefficients and $R^2$ across economic groups.

# %%
import statsmodels.formula.api as smf

formula = (
    "life_expectancy_total ~ log_gdp_per_capita + abs_latitude "
    "+ health_spend_per_capita_usd"
)
recent = panel[panel["year"] >= 2000].dropna(
    subset=[
        "life_expectancy_total",
        "log_gdp_per_capita",
        "abs_latitude",
        "health_spend_per_capita_usd",
        "dev_tier",
    ]
)

tier_models = {}
for tier in tier_order():
    sub = recent[recent["dev_tier"] == tier]
    model = smf.ols(formula, data=sub).fit()
    tier_models[tier] = model
    print(f"\n{'=' * 60}\n{tier.upper()} (n={len(sub)})\n{'=' * 60}")
    print(model.summary().tables[1])
    print(f"R-squared: {model.rsquared:.3f}")
# Out:
# ...
# DEVELOPING (n=3204)
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      29.6121      0.912     32.473      0.000      27.824      31.400
# log_gdp_per_capita              4.5618      0.130     35.035      0.000       4.307       4.817
# abs_latitude                    0.1152      0.006     18.134      0.000       0.103       0.128
# health_spend_per_capita_usd    -0.0013      0.001     -2.452      0.014      -0.002      -0.000
# ...
# R-squared: 0.531
#
# ...
# TRANSITIONAL (n=745)
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      35.3310      4.787      7.381      0.000      25.934      44.729
# ...

# %% [markdown]
# **Interpretation:** Log GDP is positive and significant in every tier. Latitude is significant in developing and transitional countries but not in developed ones, which fits our hypothesis that wealthier nations are less constrained by geography. $R^2$ is highest for developing countries, so these three predictors explain more of the variation there than in developed nations.

# %% [markdown]
# ### Analysis 2 — SVM classification of development tier
#
# We use `sklearn.svm.SVC` to classify countries into developing, transitional, or developed tiers from the same three predictors. This gives a second technique (classification vs regression) and shows how well economic and geographic features alone can recover our GDP-based tier labels.

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

features = ["log_gdp_per_capita", "abs_latitude", "health_spend_per_capita_usd"]
svm_data = recent.dropna(subset=features + ["dev_tier"])

X = svm_data[features]
y = svm_data["dev_tier"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=108, stratify=y
)

svm_model = make_pipeline(
    StandardScaler(),
    SVC(kernel="rbf", random_state=108),
)
svm_model.fit(X_train, y_train)
y_pred = svm_model.predict(X_test)

print(f"Test accuracy: {svm_model.score(X_test, y_test):.3f}\n")
print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred, labels=tier_order())
fig, ax = plt.subplots(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    xticklabels=tier_order(),
    yticklabels=tier_order(),
    cmap="Blues",
    ax=ax,
)
ax.set(xlabel="Predicted tier", ylabel="Actual tier", title="SVC confusion matrix")
plt.tight_layout()
plt.show()
# Out:
# Test accuracy: 0.981
#
#               precision    recall  f1-score   support
#
#    developed       0.93      0.92      0.92        97
#   developing       1.00      1.00      1.00       801
# transitional       0.94      0.95      0.94       186
#
#     accuracy                           0.98      1084
#    macro avg       0.95      0.95      0.95      1084
# weighted avg       0.98      0.98      0.98      1084

# %% [markdown]
# **Interpretation:** SVC achieves high accuracy because log GDP largely determines our tier definitions. Most misclassifications occur between adjacent tiers (developing vs transitional), where GDP thresholds overlap. Latitude adds little beyond GDP for tier classification, which matches Analysis 1—geography matters more for predicting life expectancy within tiers than for separating tiers themselves.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [ ] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#  - [ ] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#  > We have started thinking about how we could test the downstream results for biased outcomes by not using region as a feature to test for as to avoid generalizing based on race
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [ ] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  > Our datasets relys on grouping countries into large groups (eg. Middle East, South East Asia). This limits the effectiveness of this study because we can only generalize countries with significant differences, we are even missing different ethnic groups within these countries that are not being represented.
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#  >  Since we grouping countries into larger groupings, this limits our analysis because the countries with these groups have vastly different cultures and values that we might be omit some variables that exist within individual countries but does not show itself in these region groups and we are generalizing these geographical areas to some sort of shared result when that is not true.
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  > We worry that if we wrongly report our underlying data in any way that we can draw to a conclusion that could be used to harm any group that is already globally marginalized(eg. inheirently biased terms 1st World vs 3rd World)
#  - [ ] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  > We have to consider the fact that if we use global data that groups areas like Europe and Middle East we are effectively using these variables as proxies for race, we must rely on other factors other than purely geographical to find results.
#  - [] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  > We have decided to have some sort of documentation that explains our thoughtprocess for decisions in our model and to continously update this document as we move further into this research
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#  >  We can effictively communicate the shortcomings of this model to relavent stakeholders by describing some of the problems that come with our analysis (e.g data selection, what features we choose to test)
#
# ### E. Deployment
#  - [] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  > We have considered that if our results end up harming a group we should a plan in place to prevent future harm and other ways to frame the analysis in such a way that it doesn't hurt them in an un-intended way.
#  - [] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#  > This analysis might be used to justify more racisim against other groups based on our results, we have started taking steps towards a plan to try and mitigate these unwanted effects.

# %% [markdown]
# ## Discusison and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class
